# %% [markdown]
# ## Problem Statement
# As we all know, Cristiano Ronaldo is a legend in the football world. He has played a thousand games and scored hundreds of goals. Now, given the dataset of Cristiano Ronaldo's "attempts" on the goal target, in all his recorded and unrecorded matches, predict if he has scored a goal or not. Formally, you are given a dataset of attempts taken by Ronaldo, predict if he scored a goal or not.

# %% [markdown]
# ### Instruction
# This dataset contains the records of all the attempts Ronaldo has taken. The column "is_goal" has a missing value for all the rows you need to predict the value of "is_goal". Extract the rows with missing "is_goal" value and submit your prediction as the probability [0.0 -1.0] of the goal scored.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  match_event_id  location_x  location_y  remaining_min  \
# 0           0            10.0       167.0        72.0           10.0
# 1           1            12.0      -157.0         0.0           10.0
# 2           2            35.0      -101.0       135.0            7.0
# 3           3            43.0       138.0       175.0            6.0
# 4           4           155.0         0.0         0.0            NaN
#
#    power_of_shot  knockout_match game_season  remaining_sec  distance_of_shot  \
# 0            1.0             0.0     2000-01           27.0              38.0
# 1            1.0             0.0     2000-01           22.0              35.0
# 2            1.0             0.0     2000-01           45.0              36.0
# 3            1.0             0.0     2000-01           52.0              42.0
# 4            2.0             0.0     2000-01           19.0              20.0
#
#    ...                 lat/lng type_of_shot type_of_combined_shot  match_id  \
# 0  ...  45.539131, -122.651648    shot - 30                   NaN  20000012
# 1  ...  45.539131, -122.651648    shot - 45                   NaN  20000012
# 2  ...  45.539131, -122.651648    shot - 25                   NaN  20000012
# 3  ...  45.539131, -122.651648          NaN              shot - 3  20000012
# 4  ...  45.539131, -122.651648          NaN              shot - 1  20000012
#
#       team_id remaining_min.1 power_of_shot.1  knockout_match.1  \
# 0  1610612747           10.00             1.0            50.608
# 1  1610612747           10.00             1.0            28.800
# 2  1610612747           92.64             1.0             0.000
# 3  1610612747             NaN             1.0           122.608
# 4  1610612747           42.64             2.0             0.000
#
#   remaining_sec.1 distance_of_shot.1
# 0         54.2000               38.0
# 1         22.0000               35.0
# 2         63.7216               54.4
# 3         52.0000               42.0
# 4         19.0000               20.0
#
# [5 rows x 28 columns]

# %%
df.shape
# Out:
# (30697, 28)

# %%
df.describe()
# Out:
#          Unnamed: 0  match_event_id    location_x    location_y  \
# count  30697.000000    29134.000000  29236.000000  29157.000000
# mean   15348.000000      249.576028      7.383876     91.126933
# std     8861.604943      150.186019    110.263049     87.676395
# min        0.000000        2.000000   -250.000000    -44.000000
# 25%     7674.000000      111.000000    -68.000000      4.000000
# 50%    15348.000000      254.000000      0.000000     74.000000
# 75%    23022.000000      369.000000     95.000000    160.000000
# max    30696.000000      659.000000    248.000000    791.000000
#
#        remaining_min  power_of_shot  knockout_match  remaining_sec  \
# count   29135.000000   29211.000000    29180.000000   29103.000000
# mean        4.883233       2.519359        0.145956      28.329382
# std         3.452533       1.153976        0.353068      17.470663
# min         0.000000       1.000000        0.000000       0.000000
# 25%         2.000000       1.000000        0.000000      13.000000
# 50%         5.000000       3.000000        0.000000      28.000000
# 75%         8.000000       3.000000        0.000000      43.000000
# max        11.000000       7.000000        1.000000      59.000000
#
#        distance_of_shot       is_goal  shot_id_number      match_id  \
# count      29130.000000  24429.000000    29134.000000  3.069700e+04
# mean          33.448884      0.445331    15368.581039  2.476407e+07
# std            9.369656      0.497013     8866.520772  7.755175e+06
# min           20.000000      0.000000        1.000000  2.000001e+07
# 25%           25.000000      0.000000     7693.250000  2.050008e+07
# 50%           35.000000      0.000000    15378.500000  2.090035e+07
# 75%           41.000000      1.000000    23055.750000  2.960047e+07
# max           99.000000      1.000000    30697.000000  4.990009e+07
#
#             team_id  remaining_min.1  power_of_shot.1  knockout_match.1  \
# count  3.069700e+04     29162.000000     29158.000000      29204.000000
# mean   1.610613e+09        18.204615        15.994109         16.599402
# std    0.000000e+00        29.416973        29.676815         35.172016
# min    1.610613e+09         0.000000         1.000000          0.000000
# 25%    1.610613e+09         3.000000         2.000000          0.000000
# 50%    1.610613e+09         6.000000         3.000000          0.000000
# 75%    1.610613e+09        11.000000         4.000000          1.000000
# max    1.610613e+09       128.761600       118.360000        141.352320
#
#        remaining_sec.1  distance_of_shot.1
# count     29158.000000        29129.000000
# mean         39.027303           38.801852
# std          29.835284           18.787711
# min           0.000000            9.400000
# 25%          17.000000           26.000000
# 50%          35.000000           36.000000
# 75%          52.000000           44.000000
# max         144.785600          115.728000

# %%
# Percentage of NA values in columns
df.isna().mean().round(4) * 100
# Out:
# Unnamed: 0                0.00
# match_event_id            5.09
# location_x                4.76
# location_y                5.02
# remaining_min             5.09
# power_of_shot             4.84
# knockout_match            4.94
# game_season              19.10
# remaining_sec             5.19
# distance_of_shot          5.10
# is_goal                  20.42
# area_of_shot              4.89
# shot_basics               5.13
# range_of_shot             5.09
# team_name                 5.00
# date_of_game              5.05
# home/away                 4.88
# shot_id_number            5.09
# lat/lng                   5.10
# type_of_shot             49.78
# type_of_combined_shot    50.22
# match_id                  0.00
# team_id                   0.00
# remaining_min.1           5.00
# power_of_shot.1           5.01
# knockout_match.1          4.86
# remaining_sec.1           5.01
# distance_of_shot.1        5.11
# dtype: float64

# %%
# Replacing missing value of col A with value of col B
df['remaining_min'].fillna(df['remaining_min.1'], inplace=True)
df['power_of_shot'].fillna(df['power_of_shot.1'], inplace=True)
df['knockout_match'].fillna(df['knockout_match.1'], inplace=True)
df['remaining_sec'].fillna(df['remaining_sec.1'], inplace=True)
df['distance_of_shot'].fillna(df['distance_of_shot.1'], inplace=True)

# Dropping unnecessary cols
df = df.drop(['remaining_min.1', 'power_of_shot.1', 'knockout_match.1', 'remaining_sec.1', 'distance_of_shot.1',
             'Unnamed: 0', 'match_id', 'team_id', 'match_event_id', 'team_name', 'home/away', 'shot_id_number',
             'type_of_shot', 'type_of_combined_shot'], axis=1)
df.head()
# Out:
#    location_x  location_y  remaining_min  power_of_shot  knockout_match  \
# 0       167.0        72.0          10.00            1.0             0.0
# 1      -157.0         0.0          10.00            1.0             0.0
# 2      -101.0       135.0           7.00            1.0             0.0
# 3       138.0       175.0           6.00            1.0             0.0
# 4         0.0         0.0          42.64            2.0             0.0
#
#   game_season  remaining_sec  distance_of_shot  is_goal  \
# 0     2000-01           27.0              38.0      NaN
# 1     2000-01           22.0              35.0      0.0
# 2     2000-01           45.0              36.0      1.0
# 3     2000-01           52.0              42.0      0.0
# 4     2000-01           19.0              20.0      1.0
#
#             area_of_shot shot_basics    range_of_shot          team_name  \
# 0          Right Side(R)   Mid Range        16-24 ft.  Manchester United
# 1           Left Side(L)   Mid Range         8-16 ft.  Manchester United
# 2   Left Side Center(LC)   Mid Range        16-24 ft.  Manchester United
# 3  Right Side Center(RC)   Mid Range        16-24 ft.  Manchester United
# 4              Center(C)   Goal Area  Less Than 8 ft.                NaN
#
#   date_of_game   home/away  shot_id_number                 lat/lng
# 0   2000-10-31  MANU @ POR             1.0  45.539131, -122.651648
# 1   2000-10-31  MANU @ POR             2.0  45.539131, -122.651648
# 2   2000-10-31         NaN             3.0  45.539131, -122.651648
# 3   2000-10-31  MANU @ POR             4.0  45.539131, -122.651648
# 4   2000-10-31  MANU @ POR             5.0  45.539131, -122.651648

# %%
df['remaining_min'].fillna((df['remaining_min'].mean()), inplace=True)
df['power_of_shot'].fillna((df['power_of_shot'].mean()), inplace=True)
df['remaining_sec'].fillna((df['remaining_sec'].mean()), inplace=True)
df['distance_of_shot'].fillna((df['distance_of_shot'].mean()), inplace=True)
df.head()

# %%
fig, ax = plt.subplots(figsize=(10,10))  
sns.heatmap(df.corr(), annot=True,cmap = 'Blues', linewidths=.5, ax=ax)

# %%
df.isna().mean().round(4) * 100
# Out:
# location_x           4.76
# location_y           5.02
# remaining_min        0.26
# power_of_shot        0.23
# knockout_match       0.24
# game_season         19.10
# remaining_sec        0.25
# distance_of_shot     0.32
# is_goal             20.42
# area_of_shot         4.89
# shot_basics          5.13
# range_of_shot        5.09
# team_name            5.00
# date_of_game         5.05
# home/away            4.88
# shot_id_number       5.09
# lat/lng              5.10
# dtype: float64

# %%
# Creating testing dataset
test = df[df['is_goal'] != 1.0]
test = test[test['is_goal'] != 0.0]
test.shape
# Out:
# (6268, 17)

# %%
# Creating training dataset
train = df.dropna(subset=['is_goal'])
train.shape
# Out:
# (24429, 17)

# %%
# Checking if splitting of test and train is done correctly
test.shape[0] + train.shape[0]
# Out:
# 30697

# %%
train.describe()
# Out:
#          location_x    location_y  remaining_min  power_of_shot  \
# count  23273.000000  23184.000000   24361.000000   24372.000000
# mean       7.494178     91.461180       5.562606       3.125360
# std      110.126457     88.041628       8.237286       6.898641
# min     -250.000000    -44.000000       0.000000       1.000000
# 25%      -67.000000      4.000000       2.000000       1.000000
# 50%        0.000000     74.000000       5.000000       3.000000
# 75%       95.000000    160.000000       8.000000       4.000000
# max      248.000000    791.000000     127.761600     118.360000
#
#        knockout_match  remaining_sec  distance_of_shot       is_goal  \
# count    24369.000000   24371.000000      24351.000000  24429.000000
# mean         0.904685      28.888912         33.724456      0.445331
# std          8.243384      18.556647         10.036136      0.497013
# min          0.000000       0.000000          9.400000      0.000000
# 25%          0.000000      13.000000         25.000000      0.000000
# 50%          0.000000      28.000000         35.000000      0.000000
# 75%          0.000000      44.000000         41.000000      1.000000
# max        133.608000     142.785600        113.728000      1.000000
#
#        shot_id_number
# count    23179.000000
# mean     15343.145865
# std       8869.100024
# min          2.000000
# 25%       7659.500000
# 50%      15356.000000
# 75%      22998.500000
# max      30697.000000

# %%
train.isna().mean().round(4) * 100
# Out:
# location_x           4.73
# location_y           5.10
# remaining_min        0.28
# power_of_shot        0.23
# knockout_match       0.25
# game_season         18.96
# remaining_sec        0.24
# distance_of_shot     0.32
# is_goal              0.00
# area_of_shot         4.84
# shot_basics          5.25
# range_of_shot        5.11
# team_name            4.96
# date_of_game         5.06
# home/away            4.97
# shot_id_number       5.12
# lat/lng              5.10
# dtype: float64
